# %%
import pandas as pd
import sklearn as skl
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree, metrics, datasets, linear_model, model_selection

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00560/SeoulBikeData.csv', encoding_errors='ignore')
df
# Out:
#             Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 0     01/12/2017                254     0            -5.2           37
# 1     01/12/2017                204     1            -5.5           38
# 2     01/12/2017                173     2            -6.0           39
# 3     01/12/2017                107     3            -6.2           40
# 4     01/12/2017                 78     4            -6.0           36
# ...          ...                ...   ...             ...          ...
# 8755  30/11/2018               1003    19             4.2           34
# 8756  30/11/2018                764    20             3.4           37
# 8757  30/11/2018                694    21             2.6           39
# 8758  30/11/2018                712    22             2.1           41
# 8759  30/11/2018                584    23             1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# ...

# %%
xval = model_selection.KFold(10, shuffle=True)

# model = linear_model.LinearRegression()
model = tree.DecisionTreeRegressor(min_samples_leaf=20)
features = ['Temperature(C)', 'Hour', 'Wind speed (m/s)', 'Visibility (10m)']

X = df[features]
y = df['Rented Bike Count']

results = model_selection.cross_validate(model, X, y, cv=xval, return_train_score=True, scoring='r2')
results
# Out:
# {'fit_time': array([0.01650858, 0.01218271, 0.01300335, 0.01296067, 0.01402926,
#         0.01216936, 0.01343131, 0.01248932, 0.01134944, 0.01200056]),
#  'score_time': array([0.00091004, 0.00201917, 0.00099826, 0.00211906, 0.000875  ,
#         0.00090837, 0.00101089, 0.00099969, 0.00191736, 0.00099254]),
#  'test_score': array([0.64998561, 0.64523292, 0.64681307, 0.60809935, 0.67250933,
#         0.61622293, 0.601414  , 0.63892566, 0.61452712, 0.6663417 ]),
#  'train_score': array([0.71798992, 0.72104139, 0.7166799 , 0.71755284, 0.71699963,
#         0.72029089, 0.72341349, 0.71723057, 0.72044325, 0.71799349])}
